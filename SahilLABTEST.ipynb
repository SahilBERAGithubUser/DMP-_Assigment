# %%
import pandas as pd

# %%
df=pd.read_excel("Book1.xlsx")

# %%
df
# Out:
#    emp_id   age      sal  bop
# 0       1  25.0  50000.0  2.0
# 1       2  30.0  60000.0  5.0
# 2       3   NaN  55000.0  4.0
# 3       4  35.0      NaN  6.0
# 4       5  40.0  70000.0  NaN
# 5       6   NaN  72000.0  8.0

# %%
df.mean()
# Out:
# emp_id        3.5
# age          32.5
# sal       61400.0
# bop           5.0
# dtype: float64

# %%
pip install pandas

# %%
a=df.mean()
print(a)
# Out:
# emp_id        3.5
# age          32.5
# sal       61400.0
# bop           5.0
# dtype: float64

# %%
df.fillna(a)
# Out:
#    emp_id   age      sal  bop
# 0       1  25.0  50000.0  2.0
# 1       2  30.0  60000.0  5.0
# 2       3  32.5  55000.0  4.0
# 3       4  35.0  61400.0  6.0
# 4       5  40.0  70000.0  5.0
# 5       6  32.5  72000.0  8.0

# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\sahil\Downloads\archive\diabetes.csv')

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.dropna()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.dropna(inplace=True)

# %%
df.fillna(999)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df["BMI"].fillna(22)
# Out:
# 0      33.6
# 1      26.6
# 2      23.3
# 3      28.1
# 4      43.1
#        ...
# 763    32.9
# 764    36.8
# 765    26.2
# 766    30.1
# 767    30.4
# Name: BMI, Length: 768, dtype: float64

# %%
x=df["BMI"].mean()
df["BMI"].fillna(x)
# Out:
# 0      33.6
# 1      26.6
# 2      23.3
# 3      28.1
# 4      43.1
#        ...
# 763    32.9
# 764    36.8
# 765    26.2
# 766    30.1
# 767    30.4
# Name: BMI, Length: 768, dtype: float64

# %%
x=df["Insulin"].median()

# %%
df["Insulin"].fillna(x)
# Out:
# 0        0
# 1        0
# 2        0
# 3       94
# 4      168
#       ...
# 763    180
# 764      0
# 765    112
# 766      0
# 767      0
# Name: Insulin, Length: 768, dtype: int64

# %%
x=df["Insulin"].mode()[0]

# %%
df["Insulin"].fillna(x)
# Out:
# 0        0
# 1        0
# 2        0
# 3       94
# 4      168
#       ...
# 763    180
# 764      0
# 765    112
# 766      0
# 767      0
# Name: Insulin, Length: 768, dtype: int64

# %%
#CleaningDataofWrongFormat
df['BloodPressure']
# Out:
# 0      72
# 1      66
# 2      64
# 3      66
# 4      40
#        ..
# 763    76
# 764    70
# 765    72
# 766    60
# 767    70
# Name: BloodPressure, Length: 768, dtype: int64

# %%
#RemovingDuplicates
print(df.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 763    False
# 764    False
# 765    False
# 766    False
# 767    False
# Length: 768, dtype: bool

# %%
df.drop_duplicates()
# Out:
#      Pregnancies                       Glucose  BloodPressure  SkinThickness  \
# 0              6 1970-01-01 00:00:00.000000148             72             35
# 1              1 1970-01-01 00:00:00.000000085             66             29
# 2              8 1970-01-01 00:00:00.000000183             64              0
# 3              1 1970-01-01 00:00:00.000000089             66             23
# 4              0 1970-01-01 00:00:00.000000137             40             35
# ..           ...                           ...            ...            ...
# 763           10 1970-01-01 00:00:00.000000101             76             48
# 764            2 1970-01-01 00:00:00.000000122             70             27
# 765            5 1970-01-01 00:00:00.000000121             72             23
# 766            1 1970-01-01 00:00:00.000000126             60              0
# 767            1 1970-01-01 00:00:00.000000093             70             31
#
# ...

# %%
#Data_Correlation
df[['Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age']].corr()
# Out:
#                            Glucose  BloodPressure  SkinThickness   Insulin  \
# Glucose                   1.000000       0.152590       0.057328  0.331357
# BloodPressure             0.152590       1.000000       0.207371  0.088933
# SkinThickness             0.057328       0.207371       1.000000  0.436783
# Insulin                   0.331357       0.088933       0.436783  1.000000
# BMI                       0.221071       0.281805       0.392573  0.197859
# DiabetesPedigreeFunction  0.137337       0.041265       0.183928  0.185071
# Age                       0.263514       0.239528      -0.113970 -0.042163
#
#                                BMI  DiabetesPedigreeFunction       Age
# Glucose                   0.221071                  0.137337  0.263514
# BloodPressure             0.281805                  0.041265  0.239528
# SkinThickness             0.392573                  0.183928 -0.113970
# Insulin                   0.197859                  0.185071 -0.042163
# ...

# %%
df.describe()
# Out:
#        Pregnancies                        Glucose  BloodPressure  \
# count   768.000000                            768     768.000000
# mean      3.845052  1970-01-01 00:00:00.000000120      69.105469
# min       0.000000            1970-01-01 00:00:00       0.000000
# 25%       1.000000  1970-01-01 00:00:00.000000099      62.000000
# 50%       3.000000  1970-01-01 00:00:00.000000117      72.000000
# 75%       6.000000  1970-01-01 00:00:00.000000140      80.000000
# max      17.000000  1970-01-01 00:00:00.000000199     122.000000
# std       3.369578                            NaN      19.355807
#
#        SkinThickness     Insulin         BMI  DiabetesPedigreeFunction  \
# count     768.000000  768.000000  768.000000                768.000000
# mean       20.536458   79.799479   31.992578                  0.471876
# min         0.000000    0.000000    0.000000                  0.078000
# 25%         0.000000    0.000000   27.300000                  0.243750
# ...

# %%
#Adding new column in the data file
df['col']=5

# %%
df
# Out:
#      Pregnancies                       Glucose  BloodPressure  SkinThickness  \
# 0              6 1970-01-01 00:00:00.000000148             72             35
# 1              1 1970-01-01 00:00:00.000000085             66             29
# 2              8 1970-01-01 00:00:00.000000183             64              0
# 3              1 1970-01-01 00:00:00.000000089             66             23
# 4              0 1970-01-01 00:00:00.000000137             40             35
# ..           ...                           ...            ...            ...
# 763           10 1970-01-01 00:00:00.000000101             76             48
# 764            2 1970-01-01 00:00:00.000000122             70             27
# 765            5 1970-01-01 00:00:00.000000121             72             23
# 766            1 1970-01-01 00:00:00.000000126             60              0
# 767            1 1970-01-01 00:00:00.000000093             70             31
#
# ...

# %%
#column deletion in dataframe
df = df.drop('SkinThickness', axis=1)

# %%
df
# Out:
#      Pregnancies                       Glucose  BloodPressure  Insulin   BMI  \
# 0              6 1970-01-01 00:00:00.000000148             72        0  33.6
# 1              1 1970-01-01 00:00:00.000000085             66        0  26.6
# 2              8 1970-01-01 00:00:00.000000183             64        0  23.3
# 3              1 1970-01-01 00:00:00.000000089             66       94  28.1
# 4              0 1970-01-01 00:00:00.000000137             40      168  43.1
# ..           ...                           ...            ...      ...   ...
# 763           10 1970-01-01 00:00:00.000000101             76      180  32.9
# 764            2 1970-01-01 00:00:00.000000122             70        0  36.8
# 765            5 1970-01-01 00:00:00.000000121             72      112  26.2
# 766            1 1970-01-01 00:00:00.000000126             60        0  30.1
# 767            1 1970-01-01 00:00:00.000000093             70        0  30.4
#
# ...

# %%
#Slicing in Pandas
